# %%
3+4*2
# Out:
# 11

# %%
for n in range(5):
    print(2*n)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
import numpy
import matplotlib.pyplot

t = numpy.linspace(0, 4*numpy.pi, 101)
x = numpy.sin(t + numpy.pi/3)

matplotlib.pyplot.plot(t, x)

# %% [markdown]
# # Markdown
# ## 해딩 2
#
# 수식을 표현할 때는 LaTeX 수식 표현 문법을 이용합니다.
# 위에 있는 그래프의 식은 다음과 같습니다.
# $
# x(t) = \sin \left( t + \frac{\pi}{3} \right), 0 \le t \le 4\pi
# $
# $$
# x(t) = \sin \left( t + \frac{\pi}{3} \right), 0 \le t \le 4\pi
# $$

# %% [raw]
# import numpy
# import matplotlib.pyplot
#
# t = numpy.linspace(0, 4*numpy.pi, 101)
# x = numpy.sin(t + numpy.pi/3)
#
# matplotlib.pyplot.plot(t, x)

# %% [raw]
# # Markdown
# ## 해딩 2
#
# 수식을 표현할 때는 LaTeX 수식 표현 문법을 이용합니다.
# 위에 있는 그래프의 식은 다음과 같습니다.
# $$
# x(t) = \sin \left( t + \frac{\pi}{3} \right), 0 \le t \le 4\pi
# $$

# %% [markdown]
# # Markdown에서 수식 사용하기
# ## 그리스어 알파벳
# \alpha, \beta, \gamma, \delta, \epsilon, \zeta, \eta, \theta, \iota, \kappa, \lambda, \mu, \nu, \xi, \pi, \rho, \sigma, \tau, \upsilon, \phi, \chi, \psi, \omega
# $
# \alpha, \beta, \gamma, \delta, \epsilon, \zeta, \eta, \theta, \iota, \kappa, \lambda, \mu, \nu, \xi, \pi, \rho, \sigma, \tau, \upsilon, \phi, \chi, \psi, \omega
# $
# A, B, \Gamma, \Delta, E, Z, H, \Theta, I, K, \Lambda, M, N, \Xi, 0, \Pi, P, \sigma, T, \Upsilon, \Phi, X, \Psi, \Omega
# $
# A, B, \Gamma, \Delta, E, Z, H, \Theta, I, K, \Lambda, M, N, \Xi, 0, \Pi, P, \sigma, T, \Upsilon, \Phi, X, \Psi, \Omega
# $

# %% [markdown]
# * 선형 회기
# $
#     \hat{y} = \theta_0 + \theta_1 x_1
# $
# *
